# %% [markdown]
# # Olympic Effect with EuroSAT
#
# ## 2020년 09월 01일 안상호

# %%
from pathlib import Path

# Sangho Workspace|
root_dir = Path("/home/jovyan/")
base_dir = root_dir  / 'Land-Cls'

data_path = base_dir / "data"

# %%
import sys
import os

# Google Colab Version
# sys.path.append(str(base_dir))


# Local Version
PACKAGE_PARENT = '..'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser("__file__"))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))

# %%
from fastai.vision import *
from fastai.vision import image as im
from utils import preprocess, model #earth

# %% [markdown]
# # 1. Load  Classifier

# %%
parameters = {
    "path" : data_path / "eurosat",
    "bs" : 64, 
    "size" : 128, 
    "valid_pct" : 0.2,

    "metrics" : [accuracy],
    "pretrained" : False, 
    "load_dir": base_dir / "learn" / "euro-res50-2"
}

vis = model.FastVision(models.resnet50, parameters, task="classification")

# %% [markdown]
# # 2. Predict Land Cover

# %%
df_location = pd.DataFrame([["알펜시아", 37.658251, 128.669856, "PC_01_ Alpensia.jpg"],
                            ["진부역", 37.642935, 128.574451, "PC_02_Station.jpg"],
                            ["올림픽 게이트웨이", 37.668117, 128.705676, "PC_03_Gate.jpg"],
                            ["자연휴양", 37.705692, 128.720683, "PC_04_Nature.jpg"],
                            ["평창역", 37.562846,  128.429930, "PC_05_Station.jpg"]], columns=["name", "lat", "lon", "image_name"])

df_location.head()
# Out:
#         name        lat         lon           image_name
# 0       알펜시아  37.658251  128.669856  PC_01_ Alpensia.jpg
# 1        진부역  37.642935  128.574451    PC_02_Station.jpg
# 2  올림픽 게이트웨이  37.668117  128.705676       PC_03_Gate.jpg
# 3       자연휴양  37.705692  128.720683     PC_04_Nature.jpg
# 4        평창역  37.562846  128.429930    PC_05_Station.jpg

# %%
cols = columns=["name", "year", 'AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial',
                'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']

# %%
years = ["2016", "2017", "2018", "2019", "2020"]
result_list = []
for idx, row in df_location.iterrows():
    for year in years:
        input_img = im.open_image(data_path/ "olympic" / f"y{year}_{row.image_name}")
        meta_list = [row["name"], year]
        result_list.append(meta_list + list(vis.learn.predict(input_img)[2].detach().numpy()))
        

        
df_result = pd.DataFrame(result_list, columns=cols)
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "

# %%
df_result
# Out:
#          name  year    AnnualCrop        Forest  HerbaceousVegetation  \
# 0        알펜시아  2016  2.840511e-07  1.158073e-06              0.000187
# 1        알펜시아  2017  4.351833e-06  2.670083e-05              0.015535
# 2        알펜시아  2018  9.705155e-07  2.428026e-06              0.000726
# 3        알펜시아  2019  4.621219e-06  1.233073e-05              0.007785
# 4        알펜시아  2020  7.003116e-08  9.441899e-07              0.000109
# 5         진부역  2016  1.839276e-05  1.507337e-05              0.047385
# 6         진부역  2017  5.006456e-06  2.125771e-05              0.018399
# 7         진부역  2018  2.670315e-06  3.432371e-06              0.000804
# 8         진부역  2019  5.251713e-06  2.320455e-05              0.005716
# 9         진부역  2020  8.413044e-06  2.072960e-05              0.005100
# 10  올림픽 게이트웨이  2016  1.895104e-08  8.192671e-08              0.000010
# 11  올림픽 게이트웨이  2017  1.998413e-07  4.956503e-07              0.000134
# 12  올림픽 게이트웨이  2018  2.738956e-09  1.136399e-08              0.000002
# 13  올림픽 게이트웨이  2019  5.701773e-09  3.342733e-08              0.000004
# 14  올림픽 게이트웨이  2020  7.137864e-09  3.735197e-08              0.000005
# 15       자연휴양  2016  3.612517e-04  2.284874e-04              0.107685
# 16       자연휴양  2017  5.690679e-05  4.451703e-04              0.222692
# 17       자연휴양  2018  2.433396e-04  2.852310e-04              0.147887
# 18       자연휴양  2019  1.467299e-05  5.794011e-05              0.008088
# 19       자연휴양  2020  1.869050e-05  2.973223e-05              0.006401
# 20        평창역  2016  1.553925e-05  3.388004e-04              0.232023
# 21        평창역  2017  3.241114e-05  1.356514e-03              0.837686
# 22        평창역  2018  4.154201e-05  4.172228e-04              0.207756
# 23        평창역  2019  2.973658e-06  7.113397e-05              0.016030
# 24        평창역  2020  2.389930e-06  9.648230e-05              0.006215
#
#      Highway  Industrial       Pasture  PermanentCrop  Residential  \
# 0   0.000098    0.000454  2.976881e-07   3.266488e-05     0.999217
# 1   0.000249    0.006093  2.563366e-06   3.941742e-04     0.977400
# 2   0.000087    0.002034  6.232999e-07   5.784683e-05     0.997071
# 3   0.000493    0.009283  1.809683e-06   1.501019e-04     0.982193
# 4   0.000063    0.002044  1.715530e-07   5.209935e-06     0.997772
# 5   0.017764    0.171239  5.440181e-06   2.238518e-02     0.741032
# 6   0.029263    0.106465  2.907812e-06   9.356370e-04     0.844689
# 7   0.010862    0.057994  2.105547e-06   1.007417e-03     0.929290
# 8   0.003799    0.027400  5.691023e-06   4.511404e-04     0.962446
# 9   0.008317    0.094894  1.097173e-05   2.360557e-03     0.889166
# 10  0.002532    0.000669  3.000693e-09   1.509173e-06     0.996787
# 11  0.009579    0.001927  9.687653e-09   5.021771e-06     0.988348
# 12  0.000264    0.000139  4.236912e-10   1.916169e-07     0.999595
# 13  0.000211    0.000072  3.001358e-09   3.226154e-07     0.999712
# 14  0.000166    0.000480  5.594619e-09   7.179640e-07     0.999348
# 15  0.006639    0.033007  2.131879e-04   8.548441e-03     0.842873
# 16  0.001674    0.004837  2.425042e-05   2.544675e-03     0.765868
# 17  0.005688    0.014240  8.667933e-05   5.249569e-03     0.825727
# 18  0.001616    0.009072  8.671068e-06   4.250986e-04     0.980581
# 19  0.005462    0.908924  2.362385e-05   9.068622e-04     0.078165
# 20  0.000262    0.006209  1.133634e-05   1.468724e-03     0.759060
# 21  0.000542    0.010311  2.579235e-05   1.949603e-03     0.146731
# 22  0.002152    0.027630  2.234917e-05   2.162957e-03     0.759220
# 23  0.000150    0.000576  1.372351e-06   1.190224e-04     0.982913
# 24  0.000196    0.003705  4.028842e-06   1.135130e-04     0.989553
#
#            River       SeaLake
# 0   8.790150e-08  1.005742e-05
# 1   3.454696e-06  2.925625e-04
# 2   3.181404e-07  2.030121e-05
# 3   3.140683e-06  7.386923e-05
# 4   9.533061e-08  5.568774e-06
# 5   1.016352e-04  5.382150e-05
# 6   1.257281e-04  9.428228e-05
# 7   1.779853e-05  1.657083e-05
# 8   3.145504e-05  1.219704e-04
# 9   3.310679e-05  8.852168e-05
# 10  1.279655e-07  6.491419e-07
# 11  2.555886e-06  4.712351e-06
# 12  8.790225e-09  1.450748e-07
# 13  2.690977e-08  2.524492e-07
# 14  2.052321e-08  4.184238e-07
# 15  1.404206e-04  3.044067e-04
# 16  3.408036e-05  1.823557e-03
# 17  5.778991e-05  5.354869e-04
# 18  5.545494e-06  1.316755e-04
# 19  3.525248e-05  3.348139e-05
# 20  2.582815e-05  5.848467e-04
# 21  1.002628e-04  1.265487e-03
# 22  6.895074e-05  5.281849e-04
# 23  1.253712e-06  1.358667e-04
# 24  2.893565e-06  1.113868e-04
