# %% [markdown]
# # Multi-label Land Cover Classification with BigEarthNet
#
# ## 2020년 08월 31일 안상호
#
# ---
#
# # Requirement

# %%
from pathlib import Path

# Sangho Workspace|
root_dir = Path("/home/jovyan/")
base_dir = root_dir  / 'Land-Cls'

data_path = base_dir / "data"

# %%
import sys
import os

# Google Colab Version
# sys.path.append(str(base_dir))


# Local Version
PACKAGE_PARENT = '..'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser("__file__"))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))

# %%
# !pip3 install "torch==1.4" "torchvision==0.5.0"
# Out:
# Requirement already satisfied: torch==1.4 in /opt/conda/lib/python3.7/site-packages (1.4.0)
# Requirement already satisfied: torchvision==0.5.0 in /opt/conda/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torchvision==0.5.0) (1.18.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision==0.5.0) (7.1.2)

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# # 1. 기초 학습
#
# ## 1.1. DataBunch

# %%
bigearth_path = data_path / "bigearth"
output_path = bigearth_path / "train-labels.csv"

cloud_shadow_path = bigearth_path / "patches_with_cloud_and_shadow.csv"
snow_path = bigearth_path / "patches_with_seasonal_snow.csv"

# %%
files = os.listdir(bigearth_path / "BigEarthNet-v1.0")
len(files)
# Out:
# 590326

# %%
class_df = pd.read_csv(output_path)
# data_exist = class_df.image_name.apply(lambda x: x + ".jpg" in fnames)
# print(data_exist.shape)
# data_exist.head()

print(class_df.shape)
class_df.head()
# Out:
# (590326, 2)
#                              image_name  \
# 0  S2A_MSIL2A_20180508T104031_26_63.jpg
# 1  S2A_MSIL2A_20180318T093031_50_50.jpg
# 2  S2A_MSIL2A_20171002T112112_74_52.jpg
# 3   S2B_MSIL2A_20180204T94161_76_26.jpg
# 4  S2A_MSIL2A_20171015T095031_26_65.jpg
#
#                                                label
# 0  Non-irrigated arable land;Pastures;Land princi...
# 1  Non-irrigated arable land;Pastures;Complex cul...
# 2  Land principally occupied by agriculture, with...
# 3  Coniferous forest;Mixed forest;Transitional wo...
# 4  Discontinuous urban fabric;Non-irrigated arabl...

# %%
cloud_df = pd.read_csv(cloud_shadow_path, header=None).apply(lambda x: x + ".jpg")
snow_df = pd.read_csv(snow_path, header=None).apply(lambda x: x + ".jpg")

cloud_df.shape, snow_df.shape
# Out:
# ((9280, 1), (61707, 1))

# %%
cloud_mask = class_df["image_name"].isin(cloud_df[0]) 
snow_mask = class_df["image_name"].isin(snow_df[0])

# %%
class_df = class_df[~(cloud_mask | snow_mask)]
class_df
# Out:
#                                   image_name  \
# 0       S2A_MSIL2A_20180508T104031_26_63.jpg
# 1       S2A_MSIL2A_20180318T093031_50_50.jpg
# 2       S2A_MSIL2A_20171002T112112_74_52.jpg
# 4       S2A_MSIL2A_20171015T095031_26_65.jpg
# 5        S2B_MSIL2A_20170927T094019_7_19.jpg
# ...                                      ...
# 590320   S2B_MSIL2A_20180225T105019_47_4.jpg
# 590321  S2B_MSIL2A_20180511T100029_87_84.jpg
# 590322   S2B_MSIL2A_20170808T094029_3_78.jpg
# 590323   S2B_MSIL2A_20180525T94031_49_10.jpg
# 590324  S2B_MSIL2A_20180421T100031_23_85.jpg
#
#                                                     label
# 0       Non-irrigated arable land;Pastures;Land princi...
# 1       Non-irrigated arable land;Pastures;Complex cul...
# 2       Land principally occupied by agriculture, with...
# 4       Discontinuous urban fabric;Non-irrigated arabl...
# 5       Non-irrigated arable land;Complex cultivation ...
# ...                                                   ...
# 590320  Discontinuous urban fabric;Sport and leisure f...
# 590321                                      Sea and ocean
# 590322  Non-irrigated arable land;Land principally occ...
# 590323  Land principally occupied by agriculture, with...
# 590324  Discontinuous urban fabric;Non-irrigated arabl...
#
# [519339 rows x 2 columns]

# %%
class_df.to_csv(bigearth_path / "train.csv", index=False)

# %% [markdown]
# - `DataBunch` 생성

# %%
train_df = pd.read_csv(bigearth_path / "train.csv")
train_df
# Out:
#                                   image_name  \
# 0       S2A_MSIL2A_20180508T104031_26_63.jpg
# 1       S2A_MSIL2A_20180318T093031_50_50.jpg
# 2       S2A_MSIL2A_20171002T112112_74_52.jpg
# 3       S2A_MSIL2A_20171015T095031_26_65.jpg
# 4        S2B_MSIL2A_20170927T094019_7_19.jpg
# ...                                      ...
# 519334   S2B_MSIL2A_20180225T105019_47_4.jpg
# 519335  S2B_MSIL2A_20180511T100029_87_84.jpg
# 519336   S2B_MSIL2A_20170808T094029_3_78.jpg
# 519337   S2B_MSIL2A_20180525T94031_49_10.jpg
# 519338  S2B_MSIL2A_20180421T100031_23_85.jpg
#
#                                                     label
# 0       Non-irrigated arable land;Pastures;Land princi...
# 1       Non-irrigated arable land;Pastures;Complex cul...
# 2       Land principally occupied by agriculture, with...
# 3       Discontinuous urban fabric;Non-irrigated arabl...
# 4       Non-irrigated arable land;Complex cultivation ...
# ...                                                   ...
# 519334  Discontinuous urban fabric;Sport and leisure f...
# 519335                                      Sea and ocean
# 519336  Non-irrigated arable land;Land principally occ...
# 519337  Land principally occupied by agriculture, with...
# 519338  Discontinuous urban fabric;Non-irrigated arabl...
#
# [519339 rows x 2 columns]

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

src = (ImageList.from_csv(bigearth_path, "train.csv", folder='image')
       .split_by_rand_pct(0.2, seed=42)
       .label_from_df(label_delim=';'))

# %%
data = (src.transform(tfms, size=256)
        .databunch(bs=64, no_check=True).normalize(imagenet_stats))

# %%
data.show_batch(rows=3, figsize=(12,9))
# Out:
# /opt/conda/lib/python3.7/site-packages/fastai/vision/data.py:306: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
data.train_ds.y.classes, len(data.train_ds.y.classes)
# Out:
# (['Agro-forestry areas',
#   'Airports',
#   'Annual crops associated with permanent crops',
#   'Bare rock',
#   'Beaches, dunes, sands',
#   'Broad-leaved forest',
#   'Burnt areas',
#   'Coastal lagoons',
#   'Complex cultivation patterns',
#   'Coniferous forest',
#   'Construction sites',
#   'Continuous urban fabric',
#   'Discontinuous urban fabric',
#   'Dump sites',
#   'Estuaries',
#   'Fruit trees and berry plantations',
#   'Green urban areas',
#   'Industrial or commercial units',
#   'Inland marshes',
#   'Intertidal flats',
#   'Land principally occupied by agriculture, with significant areas of natural vegetation',
#   'Mineral extraction sites',
#   'Mixed forest',
#   'Moors and heathland',
#   'Natural grassland',
#   'Non-irrigated arable land',
#   'Olive groves',
#   'Pastures',
#   'Peatbogs',
#   'Permanently irrigated land',
#   'Port areas',
#   'Rice fields',
#   'Road and rail networks and associated land',
#   'Salines',
#   'Salt marshes',
#   'Sclerophyllous vegetation',
#   'Sea and ocean',
#   'Sparsely vegetated areas',
#   'Sport and leisure facilities',
#   'Transitional woodland/shrub',
#   'Vineyards',
#   'Water bodies',
#   'Water courses'],
#  43)

# %% [markdown]
# ## 1.2. 모델 생성 및 학습

# %%
arch = models.resnet50

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
learn = cnn_learner(data, arch, metrics=[acc_02, f_score], pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /home/jovyan/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='94' class='' max='7379' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.27% [94/7379 00:21<28:10 2.6263]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.98E-02
# Min loss divided by 10: 3.02E-02

# %%
learn.fit_one_cycle(10, 5E-02)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3025' class='' max='7379' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.99% [3025/7379 09:10<13:12 0.0972]
#     </div>

# %%
learn.save(base_dir / "learn" / "bigearth-res50-test")

# %% [markdown]
# # 2. Architecture Selection

# %%
import torch
from sklearn.metrics import f1_score

@np_func
def f1_macro(inp,targ): return f1_score(targ, np.argmax(inp, axis=-1), average='macro')

@np_func
def f1_weighted(inp,targ): return f1_score(targ, np.argmax(inp, axis=-1), average='weighted')


def create_multi_cls_learner(data, arch, threshold=0.2, pretrained=True):
    acc_02 = partial(accuracy_thresh, thresh=threshold)
    
    f1_score = partial(fbeta, thresh=threshold, beta=1)
    f2_score = partial(fbeta, thresh=threshold, beta=2)
    
    f1_score.__name__ = 'f1_score'
    f2_score.__name__ = 'f2_score'
    
    # f_score = partial(fbeta, thresh=threshold)
    learn = cnn_learner(data, arch, metrics=[acc_02, f1_score, f2_score], pretrained=pretrained)  
    learn.model = nn.DataParallel(learn.model)
    return learn

# %% [markdown]
# ## 2.1. ResNet34
#
# ### With Pretraining

# %%
arch = models.resnet34

learn = create_multi_cls_learner(data, arch)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='94' class='' max='6491' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.45% [94/6491 00:17<20:03 2.8110]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.98E-02
# Min loss divided by 10: 3.02E-02

# %%
learn.fit_one_cycle(15, 5e-02)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.103789</td>
#       <td>0.096046</td>
#       <td>0.952301</td>
#       <td>0.778208</td>
#       <td>14:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.111428</td>
#       <td>0.110353</td>
#       <td>0.944881</td>
#       <td>0.739754</td>
#       <td>14:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.126457</td>
#       <td>14.271398</td>
#       <td>0.910522</td>
#       <td>0.571303</td>
#       <td>14:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.135717</td>
#       <td>0.985657</td>
#       <td>0.920387</td>
#       <td>0.687932</td>
#       <td>14:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.138071</td>
#       <td>0.861186</td>
#       <td>0.920290</td>
#       <td>0.698138</td>
#       <td>14:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.134349</td>
#       <td>1.527552</td>
#       <td>0.912466</td>
#       <td>0.539040</td>
#       <td>14:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.139380</td>
#       <td>0.164937</td>
#       <td>0.918343</td>
#       <td>0.660186</td>
#       <td>14:25</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.134568</td>
#       <td>2.321582</td>
#       <td>0.914962</td>
#       <td>0.574973</td>
#       <td>14:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.133205</td>
#       <td>0.367579</td>
#       <td>0.925435</td>
#       <td>0.672990</td>
#       <td>14:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.123678</td>
#       <td>0.672847</td>
#       <td>0.935829</td>
#       <td>0.728787</td>
#       <td>14:20</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.120304</td>
#       <td>0.126849</td>
#       <td>0.936215</td>
#       <td>0.741197</td>
#       <td>14:19</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.114238</td>
#       <td>0.255166</td>
#       <td>0.942626</td>
#       <td>0.746352</td>
#       <td>14:23</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.111030</td>
#       <td>0.103909</td>
#       <td>0.944843</td>
#       <td>0.768753</td>
#       <td>14:19</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.108675</td>
#       <td>0.098342</td>
#       <td>0.942353</td>
#       <td>0.775315</td>
#       <td>14:20</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0
21</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.113259</td>
#       <td>0.128971</td>
#       <td>0.932788</td>
#       <td>0.633216</td>
#       <td>0.698617</td>
#       <td>21:23</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.106423</td>
#       <td>0.099949</td>
#       <td>0.942192</td>
#       <td>0.696341</td>
#       <td>0.773026</td>
#       <td>21:20</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.103910</td>
#       <td>0.097758</td>
#       <td>0.943775</td>
#       <td>0.703511</td>
#       <td>0.778740</td>
#       <td>21:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>f1_score</th>
#       <th>f2_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='6491' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.36% [88/6491 00:19<23:43 0.2856]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.10E-06
# Min loss divided by 10: 1.32E-05

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-06, 1e-03))
learn.save(base_dir / "learn" / "bigearth-res50-r-2")
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.00% [1/10 21:26<3:12:55]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>f1_score</th>
#       <th>f2_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.103649</td>
#       <td>0.097295</td>
#       <td>0.943919</td>
#       <td>0.704605</td>
#       <td>0.779071</td>
#       <td>21:26</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1577' class='' max='6491' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       24.30% [1577/6491 04:38<14:27 0.1052]
#     </div>

# %% [markdown]
# ## 2.3. ResNet101

# %%
arch = models.resnet101

learn = ccreate_multi_cls_learner(data, arch)

# %% [markdown]
# ## 2.4. ResNet152

# %%
arch = models.resnet152

learn = create_multi_cls_learner(data, arch, pretrained=False)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='91' class='' max='7379' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.23% [91/7379 00:59<1:19:21 2.3687]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.98E-02
# Min loss divided by 10: 3.02E-02

# %%
learn.fit_one_cycle(15, 5e-02)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.125978</td>
#       <td>2440.798828</td>
#       <td>0.928634</td>
#       <td>0.624870</td>
#       <td>59:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.125471</td>
#       <td>4861.031738</td>
#       <td>0.911844</td>
#       <td>0.560977</td>
#       <td>59:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.139694</td>
#       <td>6587.037109</td>
#       <td>0.805013</td>
#       <td>0.428707</td>
#       <td>59:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.140240</td>
#       <td>2418.294434</td>
#       <td>0.618160</td>
#       <td>0.300314</td>
#       <td>59:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.140995</td>
#       <td>3738.331787</td>
#       <td>0.672918</td>
#       <td>0.174542</td>
#       <td>59:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.154391</td>
#       <td>2012947456.000000</td>
#       <td>0.704029</td>
#       <td>0.312036</td>
#       <td>59:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.146944</td>
#       <td>80.903961</td>
#       <td>0.876582</td>
#       <td>0.155352</td>
#       <td>59:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.147852</td>
#       <td>55.921764</td>
#       <td>0.819961</td>
#       <td>0.363807</td>
#       <td>59:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.139457</td>
#       <td>0.145025</td>
#       <td>0.931512</td>
#       <td>0.596381</td>
#       <td>59:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.137269</td>
#       <td>0.459407</td>
#       <td>0.917317</td>
#       <td>0.681617</td>
#       <td>59:21</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.134110</td>
#       <td>0.575435</td>
#       <td>0.923171</td>
#       <td>0.603582</td>
#       <td>59:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.126206</td>
#       <td>0.215723</td>
#       <td>0.932251</td>
#       <td>0.701587</td>
#       <td>59:19</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.122151</td>
#       <td>0.118863</td>
#       <td>0.931097</td>
#       <td>0.717691</td>
#       <td>59:18</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.114882</td>
#       <td>0.111002</td>
#       <td>0.935119</td>
#       <td>0.749415</td>
#       <td>59:25</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.112915</td>
#       <td>0.107365</td>
#       <td>0.934988</td>
#       <td>0.754492</td>
#       <td>59:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(base_dir / "learn" / "bigearth-res152-test")

# %%
learn.recorder.plot_losses(60000)
